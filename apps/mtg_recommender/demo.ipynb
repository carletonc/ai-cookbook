# %%
from langchain.agents import AgentExecutor, create_react_agent
from langchain_openai import OpenAI, ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

from pprint import pprint
from dotenv import load_dotenv
load_dotenv() 

from src.utils import get_vector_store

MODEL = "gpt-4.1-nano" # "gpt-4.1-mini", "gpt-3.5-turbo"
TEMPERATURE = 0.5
SYSTEM_PROMPT = """
You are a helpful AI assistant designed to accurately answer questions related to Magic The Gathering (MTG) cards. You will receive an input question and potential cards that are relevant to the question. Your task is to provide a concise, accurate, and wholistic answer to the question. You may not need to return all cards or all the related metadata for each card in the context, but you should use the provided context to inform your answer. If the question is not related to MTG cards, you should respond with "I don't know" or "I cannot answer that question."

## Question
{user_input}

## Context
{context}
"""

def get_agent(user_input: str, context: str = "") -> str:
    """Create and return an agent executor for multi-turn LLM agent."""
    llm = ChatOpenAI(
        model=MODEL, 
        temperature=TEMPERATURE, 
    )
    agent_prompt = PromptTemplate(
        input_variables=['user_input', 'context'], 
        template=SYSTEM_PROMPT 
    )
    chain = LLMChain(llm=llm, prompt=agent_prompt)
    response = chain.run(user_input=user_input, context=context)
    return response

def get_context(user_input: str, K: int = 100, feats: list = ['name', 'text', 'type', 'power', 'toughness', 'manaCost', 'colorIdentity']) -> str:
    vectorstore = get_vector_store()
    results = vectorstore.similarity_search_with_score(
        user_input, 
        k=K, 
    )
    
    # filter for results & merge metadata
    context = '|'.join(feats) + '\n' + '\n'.join(
        ['|'.join(
                [result[0].metadata[k] if k in result[0].metadata else '' for k in feats]
            ) for result in results]
        )
    return context

# %%
user_input = "Find me creatures that make squirrels."

# %%
context = get_context(user_input)
response = get_agent(user_input, context)
print(response)
# Out:
# /var/folders/t3/_06vpls11x13y6v4y5325lhr0000gn/T/ipykernel_6313/2792319249.py:34: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=agent_prompt)
# /var/folders/t3/_06vpls11x13y6v4y5325lhr0000gn/T/ipykernel_6313/2792319249.py:35: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = chain.run(user_input=user_input, context=context)
# The following MTG creatures from your list make Squirrels:
#
# 1. **Drey Keeper** — When it enters, create two 1/1 green Squirrel creature tokens.
# 2. **Squirrel Mob** — Gets +1/+1 for each other Squirrel on the battlefield.
# 3. **Squirrel Squatters** — When it attacks, create a tapped 1/1 green Squirrel token for each Attraction visited this turn.
# 4. **Nut Collector** — At the beginning of your upkeep, creates a 1/1 green Squirrel token.
# 5. **Earl of Squirrel** — Squirrellink; other Squirrels you control get +1/+1 and damage dealt by Squirrels creates Squirrel tokens.
# 6. **Chittering Doom** — Creates a 1/1 green Squirrel token whenever you roll a 4 or higher on a die.
# 7. **Squirrel Wrangler** — Sacrifice a land to create two Squirrel tokens or give Squirrels +1/+1 until end of turn.
# 8. **Chitterspitter** — Taps to create a 1/1 green Squirrel token.
# 9. **Acornelia, Fashionable Filcher** — Creates a 1/1 green Squirrel token whenever a Squirrel enters or dies.
# 10. **Deep Forest Hermit** — When it enters, create four 1/1 green Squirrel tokens.
# 11. **Deranged Hermit** — When it enters, create four 1/1 green Squirrel tokens.
# 12. **The Odd Acorn Gang** — Creates +2/+2 trample trample Squirrels and can produce multiple Squirrel tokens with its activated ability.
# 13. **Cloakwood Hermit** — When it enters, creates two tapped 1/1 green Squirrel tokens.
# 14. **Acorn Harvest** — Creates two 1/1 green Squirrel tokens.
# 15. **Chatterstorm** — Creates a 1/1 green Squirrel token.
# 16. **Hare Apparent** — Creates a number of 1/1 white Rabbit tokens, but not Squirrels.
# 17. **Wick, the Whorled Mind** — Creates a 1/1 black Snail token, not Squirrels.
# 18. **Emrakul and Chatterfang** — Creates 15 1/1 green Eldrazi Squirrel tokens.
# 19. **Maître Tree** — Creates a 1/1 green Squirrel among other tokens.
# 20. **Head of the Homestead** — When it enters, creates two 1/1 white Rabbit tokens, not Squirrels.
# 21. **Oakhollow Village** — Taps to create a green Squirrel token if you spend mana to cast a creature spell.
# 22. **Comet, Stellar Pup** — Creates two 1/1 green Squirrel tokens when its loyalty ability is activated.
# 23. **Wrenn and One** — Its -1 ability creates a 1/1 green Squirrel token.
# 24. **Valley Rotcaller** — When it attacks, creates a number of 1/1 black Rat tokens, not Squirrels.
# 25. **Serra Aviary** — Boosts flying creatures, no Squirrel tokens.
# 26. **Chatter of the Squirrel** — Creates a 1/1 green Squirrel token.
# 27. **Squirrel Sanctuary** — Creates a 1/1 green Squirrel token when it enters.
# 28. **Acorn Catapult** — Sacrifice a token to deal damage and create a Squirrel token.
# 29. **Form of the Squirrel** — Creates a 1/1 green Squirrel token when it enters.
# 30. **Storm of Squirrels (Chatterstorm and Awaken the Woods)** — Creates a 1/1 green Squirrel token.
#
# **Summary:** The primary creature cards that explicitly make Squirrels are **Drey Keeper, Squirrel Mob, Squirrel Squatters, Nut Collector, Earl of Squirrel, Chittering Doom, Squirrel Wrangler, Chitterspitter, Acornelia, Deep Forest Hermit, Deranged Hermit, The Odd Acorn Gang, Cloakwood Hermit, Acorn Harvest, Chatterstorm, Maître Tree, Oakhollow Village, Comet, Stellar Pup, Wrenn and One, Chatter of the Squirrel, Squirrel Sanctuary, Acorn Catapult, Form of the Squirrel,** and **Emrakul and Chatterfang** (which creates Eldrazi Squirrels).

# %%
vectorstore = get_vector_store()
results = vectorstore.similarity_search_with_score(
    user_input, 
    k=3, 
)

# %%
sorted(list(results[0][0].metadata.keys()))
# Out:
# ['cardName',
#  'colorIdentity',
#  'colors',
#  'convertedManaCost',
#  'firstPrinting',
#  'foreignData',
#  'hasAlternativeDeckLimit',
#  'identifiers.scryfallOracleId',
#  'isFunny',
#  'isReserved',
#  'layout',
#  'leadershipSkills.brawl',
#  'leadershipSkills.commander',
#  'leadershipSkills.oathbreaker',
#  'manaCost',
#  'manaValue',
#  'name',
#  'power',
#  'printings',
#  'purchaseUrls.cardKingdom',
#  'purchaseUrls.cardKingdomFoil',
#  'purchaseUrls.cardmarket',
#  'purchaseUrls.tcgplayer',
#  'rulings',
#  'subtypes',
#  'text',
#  'toughness',
#  'type',
#  'types']

# %%
from src.utils import load_json_file

data = load_json_file()
data
# Out:
# /Users/ccoggins/Documents/Code/GitHub/ai-cookbook/apps/mtg_recommender/src/utils.py:81: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)
# /Users/ccoggins/Documents/Code/GitHub/ai-cookbook/apps/mtg_recommender/src/utils.py:81: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)
#                              cardName          identifiers.scryfallOracleId  \
# 0                   "Ach! Hans, Run!"  a2c5ee76-6084-413c-bb70-45490d818374
# 1      "Brims" Barone, Midway Mobster  c64c31f2-c1be-414e-9dff-c3b77ba97545
# 2              "Lifetime" Pass Holder  7bf6f13a-3c90-4bda-bc84-e026828bf4d1
# 3               "Name Sticker" Goblin  acee1d16-1651-4e2c-8138-cc6456c4ee71
# 4          "Rumors of My Death . . ."  38bcba8b-2838-4ac8-9976-f9ccaa94fdba
# ...                               ...                                   ...
# 32793            Éomer, King of Rohan  4f8191e6-a6aa-4426-9014-eff4e0efee9e
# 32794         Éomer, Marshal of Rohan  b2d95950-18b3-463f-94f4-299e420751dc
# 32795          Éowyn, Fearless Knight  dcc349e9-399d-4f33-8131-d1801272466a
# 32796            Éowyn, Lady of Rohan  1ee3753c-3b6e-4182-9305-2ab757f485f0
# 32797             Éowyn, Shieldmaiden  98a2a642-a30a-43e7-b47f-4776c22d1cb0
#
#       colorIdentity   colors         manaCost  convertedManaCost  manaValue  \
# 0              G, R     G, R  {2}{R}{R}{G}{G}                6.0        6.0
# 1              B, W     B, W        {3}{W}{B}                5.0        5.0
# 2                 B        B              {B}                1.0        1.0
# 3                 R        R           {2}{R}                3.0        3.0
# 4                 B        B           {2}{B}                3.0        3.0
# ...             ...      ...              ...                ...        ...
# 32793          R, W     R, W        {3}{R}{W}                5.0        5.0
# 32794             R        R        {2}{R}{R}                4.0        4.0
# 32795          R, W     R, W        {2}{R}{W}                4.0        4.0
# 32796             W        W           {2}{W}                3.0        3.0
# 32797       R, U, W  R, U, W     {2}{U}{R}{W}                5.0        5.0
#
#        layout  side faceName  ...  edhrecSaltiness  firstPrinting  printings  \
# 0      normal  None     None  ...              NaN            UNH        UNH
# 1      normal  None     None  ...              NaN            UNF        UNF
# 2      normal  None     None  ...             0.50            UNF        UNF
# 3      normal  None     None  ...              NaN            UNF        UNF
# 4      normal  None     None  ...              NaN            UST        UST
# ...       ...   ...      ...  ...              ...            ...        ...
# 32793  normal  None     None  ...             0.32            LTC        LTC
# 32794  normal  None     None  ...             0.22            LTR  LTR, PLTR
# 32795  normal  None     None  ...             0.33            LTR  LTR, PLTR
# 32796  normal  None     None  ...             0.11            LTR        LTR
# 32797  normal  None     None  ...             0.42            LTC        LTC
#
#                                              foreignData  hand isFunny  \
# 0                                                     []  None    True
# 1                                                     []  None    True
# 2                                                     []  None   False
# 3                                                     []  None   False
# 4                                                     []  None    True
# ...                                                  ...   ...     ...
# 32793  [{'language': 'German', 'name': 'Éomer, König ...  None   False
# 32794  [{'language': 'German', 'name': 'Éomer, Marsch...  None   False
# 32795  [{'language': 'German', 'name': 'Éowyn, furcht...  None   False
# 32796  [{'language': 'German', 'name': 'Éowyn, Herrin...  None   False
# 32797  [{'language': 'German', 'name': 'Éowyn die Sch...  None   False
#
#       isReserved  life                asciiName  \
# 0          False  None                     None
# 1          False  None                     None
# 2          False  None                     None
# 3          False  None                     None
# 4          False  None                     None
# ...          ...   ...                      ...
# 32793      False  None     Eomer, King of Rohan
# 32794      False  None  Eomer, Marshal of Rohan
# 32795      False  None   Eowyn, Fearless Knight
# 32796      False  None     Eowyn, Lady of Rohan
# 32797      False  None      Eowyn, Shieldmaiden
#
#                                  name
# 0                   "Ach! Hans, Run!"
# 1      "Brims" Barone, Midway Mobster
# 2              "Lifetime" Pass Holder
# 3               "Name Sticker" Goblin
# 4          "Rumors of My Death . . ."
# ...                               ...
# 32793            Éomer, King of Rohan
# 32794         Éomer, Marshal of Rohan
# 32795          Éowyn, Fearless Knight
# 32796            Éowyn, Lady of Rohan
# 32797             Éowyn, Shieldmaiden
#
# [32798 rows x 67 columns]

# %%
sorted(data.columns.tolist())
# Out:
# ['asciiName',
#  'cardName',
#  'colorIdentity',
#  'colorIndicator',
#  'colors',
#  'convertedManaCost',
#  'defense',
#  'edhrecRank',
#  'edhrecSaltiness',
#  'faceConvertedManaCost',
#  'faceManaValue',
#  'faceName',
#  'firstPrinting',
#  'foreignData',
#  'hand',
#  'hasAlternativeDeckLimit',
#  'identifiers.scryfallOracleId',
#  'isFunny',
#  'isReserved',
#  'keywords',
#  'layout',
#  'leadershipSkills.brawl',
#  'leadershipSkills.commander',
#  'leadershipSkills.oathbreaker',
#  'legalities.alchemy',
#  'legalities.brawl',
#  'legalities.commander',
#  'legalities.duel',
#  'legalities.explorer',
#  'legalities.future',
#  'legalities.gladiator',
#  'legalities.historic',
#  'legalities.legacy',
#  'legalities.modern',
#  'legalities.oathbreaker',
#  'legalities.oldschool',
#  'legalities.pauper',
#  'legalities.paupercommander',
#  'legalities.penny',
#  'legalities.pioneer',
#  'legalities.predh',
#  'legalities.premodern',
#  'legalities.standard',
#  'legalities.standardbrawl',
#  'legalities.timeless',
#  'legalities.vintage',
#  'life',
#  'loyalty',
#  'manaCost',
#  'manaValue',
#  'name',
#  'power',
#  'printings',
#  'purchaseUrls.cardKingdom',
#  'purchaseUrls.cardKingdomEtched',
#  'purchaseUrls.cardKingdomFoil',
#  'purchaseUrls.cardmarket',
#  'purchaseUrls.tcgplayer',
#  'purchaseUrls.tcgplayerEtched',
#  'rulings',
#  'side',
#  'subtypes',
#  'supertypes',
#  'text',
#  'toughness',
#  'type',
#  'types']

# %%
data.loc[data['cardName'].str.contains('Emrakul and')]
# Out:
#                      cardName          identifiers.scryfallOracleId  \
# 8536  Emrakul and Chatterfang  3c51bc3d-9f98-4d91-bb7b-a44d48ea06f9
#
#      colorIdentity colors      manaCost  convertedManaCost  manaValue  layout  \
# 8536          B, G   None  {8}{G}{G}{G}               11.0       11.0  normal
#
#       side faceName  ...  edhrecSaltiness  firstPrinting printings  \
# 8536  None     None  ...              NaN            UNK       UNK
#
#      foreignData  hand isFunny isReserved  life asciiName  \
# 8536          []  None    True      False  None      None
#
#                          name
# 8536  Emrakul and Chatterfang
#
# [1 rows x 67 columns]

# %%
data['legalities.commander'].value_counts()
# Out:
# legalities.commander
# Legal     29533
# Banned       86
# Name: count, dtype: int64
