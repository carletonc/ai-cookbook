# %%
from pprint import pprint
from dotenv import load_dotenv
load_dotenv() 

from src.llm import query_llm, get_context
from src.data.utils import get_vector_store, load_json_file

# %% [markdown]
# user_input = "Find me creatures that make squirrels."
# context = get_context(user_input)
# response = query_llm(user_input, context)
# print(response)

# %%
vbd = get_vector_store()
vbd.similarity_search_with_relevance_scores('make squirrel tokens', k=10)
# Out:
# [(Document(id='e0931be5-3143-4282-8b53-cbbcd283c2e8', metadata={'cardName': 'Chitterspitter', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 3.0, 'edhrecRank': 3361.0, 'edhrecSaltiness': 0.21, 'firstPrinting': 'MH2', 'foreignData': '[{\'language\': \'German\', \'name\': \'Eichelspeier\', \'text\': \'Zu Beginn deines Versorgungssegments kannst du einen Spielstein opfern. Falls du dies tust, lege eine Eichelmarke auf den Eichelspeier.\\nEichhörnchen, die du kontrollierst, erhalten +1/+1 für jede Eichelmarke auf dem Eichelspeier.\\n{G}, {T}: Erzeuge einen 1/1 grünen Eichhörnchen-Kreaturenspielstein.\', \'type\': \'Artefakt\'}, {\'language\': \'Spanish\', \'name\': \'Llamacomida\', \'text\': \'Al comienzo de tu mantenimiento, puedes sacrificar una ficha. Si lo haces, pon un contador de bellotas sobre el Llamacomida.\\nLas Ardillas que controlas obtienen +1/+1 por cada contador de bellotas sobre el Llamacomida.\\n{G}, {T}: Crea una ficha de criatura Ardilla verde 1/1.\', \'type\': \'Artefacto\'}, {\'language\': \'French\', \'name\': \'Crache-glands\', \'text\': \'Au début de votre entretien, vous pouvez sacrifier un jeton. Si vous faites ainsi, mettez un marqueur « gland » sur le Crache-glands.\\nLes écureuils que vous contrôlez gagnent +1/+1 pour chaque marqueur « gland » sur le Crache-glands.\\n{G}, {T} : Créez un jeton de créature 1/1 verte Écureuil.\', \'type\': \'Artefact\'}, {\'language\': \'Italian\', \'name\': \'Sputaghiande\', \'text\': "All\'inizio del tuo mantenimento, puoi sacrificare una pedina. Se lo fai, metti un segnalino ghianda sullo Sputaghiande.\\nGli Scoiattoli che controlli prendono +1/+1 per ogni segnalino ghianda sullo Sputaghiande.\\n{G}, {T}: Crea una pedina creatura Scoiattolo 1/1 verde.", \'type\': \'Artefatto\'}, {\'language\': \'Japanese\', \'name\': \'囀り吐き\', \'text\': \'あなたのアップキープの開始時に、あなたはトークン１つを生け贄に捧げてもよい。そうしたなら、囀り吐きの上にドングリ・カウンター１個を置く。\\nあなたがコントロールしているすべてのリスは、囀り吐きの上に置かれているドングリ・カウンター１個につき＋１/＋１の修整を受ける。\\n{G}, {T}：緑の１/１のリス・クリーチャー・トークン１体を生成する。\', \'type\': \'アーティファクト\'}]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': '4a338863-d599-46e7-9c30-e11b898ae1b0', 'isFunny': False, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Legal', 'legalities.historic': 'Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Not Legal', 'legalities.premodern': 'Not Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Legal', 'legalities.vintage': 'Legal', 'manaCost': '{2}{G}', 'manaValue': 3.0, 'name': 'Chitterspitter', 'printings': 'BLC,J21,MH2,PMH2,PRM', 'purchaseUrls.cardKingdomFoil': 'https://mtgjson.com/links/928ad38e935bd0c3', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/06bcfa770714014a', 'rulings': 'None', 'type': 'Artifact', 'types': 'Artifact'}, page_content='At the beginning of your upkeep, you may sacrifice a token. If you do, put an acorn counter on this artifact.\nSquirrels you control get +1/+1 for each acorn counter on this artifact.\n{G}, {T}: Create a 1/1 green Squirrel creature token.'),
#   0.7939512135),
#  (Document(id='69c15e10-1232-4abc-9d01-38d31e475be0', metadata={'cardName': 'Nut Collector', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 6.0, 'edhrecRank': 7271.0, 'edhrecSaltiness': 0.22, 'firstPrinting': 'ODY', 'foreignData': '[{\'language\': \'German\', \'name\': \'Nüssesammler\', \'text\': \'Du kannst zu Beginn deines Versorgungssegments einen 1/1 grünen Eichhörnchenspielstein ins Spiel bringen.\\nGrenzwert Alle Eichhörnchen erhalten +2/+2. (Du hast den Grenzwert erreicht, solange sieben oder mehr Karten in deinem Friedhof sind.)\', \'type\': \'Kreatur — Druide\'}, {\'language\': \'Spanish\', \'name\': \'Recolector de nueces\', \'text\': \'Al comienzo de tu mantenimiento, puedes poner en juego una ficha de criatura Ardilla verde 1/1.\\nUmbral Todas las Ardillas obtienen +2/+2. (Tienes umbral mientras haya siete o más cartas en tu cementerio.)\', \'type\': \'Criatura — Druida\'}, {\'language\': \'French\', \'name\': \'Collecteur de noix\', \'text\': "Au début de votre entretien, vous pouvez mettre en jeu un jeton de créature 1/1 verte Écureuil.\\nSeuil — Tous les écureuils gagnent +2/+2. (Vous avez le seuil tant qu\'il y a sept cartes ou plus dans votre cimetière.)", \'type\': \'Créature : druide\'}, {\'language\': \'Italian\', \'name\': \'Raccogli Noci\', \'text\': "All\'inizio del tuo mantenimento, puoi mettere in gioco una pedina creatura Scoiattolo 1/1 verde.\\nSoglia Tutti gli Scoiattoli prendono +2/+2 (hai soglia fintanto che ci sono almeno sette carte nel tuo cimitero).", \'type\': \'Creatura — Druido\'}, {\'language\': \'Japanese\', \'name\': \'木の実拾い\'}, {\'language\': \'Portuguese (Brazil)\', \'name\': \'Catador de Nozes\', \'text\': \'No início de sua manutenção, você pode colocar em jogo uma ficha de criatura verde 1/1 do tipo Esquilo.\\nLimiar — Todos os Esquilos recebem +2/+2. (Você atinge o limiar desde que haja sete ou mais cards em seu cemitério.)\', \'type\': \'Criatura — Druida\'}]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': '4e1bc03c-e131-4422-beba-0a45a26fdf43', 'isFunny': False, 'isReserved': False, 'keywords': 'Threshold', 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Legal', 'legalities.premodern': 'Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Legal', 'manaCost': '{5}{G}', 'manaValue': 6.0, 'name': 'Nut Collector', 'power': '1', 'printings': 'DMR,ODY,PLST', 'purchaseUrls.cardKingdom': 'https://mtgjson.com/links/ac38cc0fe7f19f87', 'purchaseUrls.cardmarket': 'https://mtgjson.com/links/df6d564e87632141', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/be6afb30a47dfa16', 'rulings': "[{'date': '2022-12-08', 'text': 'Because damage remains marked on a creature until the damage is removed as the turn ends, nonlethal damage dealt to Squirrels may become lethal if the number of cards in your graveyard falls below seven.'}]", 'subtypes': 'Human,Druid', 'toughness': '1', 'type': 'Creature — Human Druid', 'types': 'Creature'}, page_content='At the beginning of your upkeep, you may create a 1/1 green Squirrel creature token.\nThreshold — All Squirrels get +2/+2 as long as seven or more cards are in your graveyard.'),
#   0.7829295695),
#  (Document(id='5ad6f12e-d129-4876-b5ec-abd10cb305a6', metadata={'cardName': 'Earl of Squirrel', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 6.0, 'firstPrinting': 'UST', 'foreignData': '[]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': 'edc4d1fb-f482-4f2b-985e-1e4d5941e574', 'isFunny': True, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Not Legal', 'legalities.duel': 'Not Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Not Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Not Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Not Legal', 'legalities.premodern': 'Not Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Not Legal', 'manaCost': '{4}{G}{G}', 'manaValue': 6.0, 'name': 'Earl of Squirrel', 'power': '4', 'printings': 'PUST,ULST,UST', 'purchaseUrls.cardKingdomFoil': 'https://mtgjson.com/links/7598fd54f8ce7df9', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/2f58cbaa782e0db7', 'rulings': "[{'date': '2018-01-19', 'text': 'If Earl of Squirrel deals damage, you’ll create 1/1 green Squirrel creature tokens at the same time the damage is dealt.'}, {'date': '2018-01-19', 'text': 'If you control two Earls of Squirrel (Earl of Squirrels? Earl ofs Squirrel?), each will get +1/+1 from the other. Other Squirrels you control will get +2/+2.'}]", 'subtypes': 'Squirrel,Noble,Advisor', 'toughness': '4', 'type': 'Creature — Squirrel Noble Advisor', 'types': 'Creature'}, page_content='Squirrellink (Damage dealt by this creature also causes you to create that many 1/1 green Squirrel creature tokens.)\nCreature tokens you control are Squirrels in addition to their other creature types.\nOther Squirrels you control get +1/+1.'),
#   0.7791425885000001),
#  (Document(id='538381c6-5b1a-461e-ba89-b41ca1d1d7e5', metadata={'cardName': 'Deranged Hermit', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 5.0, 'edhrecRank': 10755.0, 'firstPrinting': 'ULG', 'foreignData': "[{'language': 'German', 'name': 'Irrer Einsiedler', 'text': 'Echo\\nBringe vier Eichhörnchen-Spielsteine ins Spiel, wenn der Irre Einsiedler ins Spiel kommt. Behandle diese Spielsteine wie 1/1 grüne Kreaturen.\\nAlle Eichhörnchen erhalten +1/+1.', 'type': 'Beschwörung eines Elfen'}, {'language': 'Spanish', 'name': 'Ermitaño trastornado'}, {'language': 'French', 'name': 'Ermite fêlé'}, {'language': 'Italian', 'name': 'Eremita Folle'}, {'language': 'Japanese', 'name': '錯乱した隠遁者'}, {'language': 'Portuguese (Brazil)', 'name': 'Eremita Demente'}]", 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': 'b9cd714b-2ad8-4fdb-a8aa-82b17730e071', 'isFunny': False, 'isReserved': True, 'keywords': 'Echo', 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Legal', 'legalities.premodern': 'Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Legal', 'manaCost': '{3}{G}{G}', 'manaValue': 5.0, 'name': 'Deranged Hermit', 'power': '1', 'printings': 'G04,PRM,ULG,VMA', 'rulings': "[{'date': '2004-10-04', 'text': 'The Squirrel tokens get the bonus, so they are effectively 2/2 creatures until the Hermit leaves the battlefield. And they get bigger if multiple Hermits are on the battlefield.'}]", 'subtypes': 'Elf', 'toughness': '1', 'type': 'Creature — Elf', 'types': 'Creature'}, page_content='Echo {3}{G}{G} (At the beginning of your upkeep, if this came under your control since the beginning of your last upkeep, sacrifice it unless you pay its echo cost.)\nWhen this creature enters, create four 1/1 green Squirrel creature tokens.\nSquirrel creatures get +1/+1.'),
#   0.7764429150000001),
#  (Document(id='6aa37dc3-468c-4f08-9ff2-99bf9aa10a0e', metadata={'cardName': 'Chittering Doom', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 4.0, 'firstPrinting': 'UST', 'foreignData': '[]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': '7db538a8-30ed-49d6-9104-d522da8f87ea', 'isFunny': True, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Not Legal', 'legalities.duel': 'Not Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Not Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Not Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Not Legal', 'legalities.premodern': 'Not Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Not Legal', 'manaCost': '{3}{G}', 'manaValue': 4.0, 'name': 'Chittering Doom', 'printings': 'UST', 'purchaseUrls.cardKingdom': 'https://mtgjson.com/links/faf361028acb37a4', 'purchaseUrls.cardKingdomFoil': 'https://mtgjson.com/links/641e227deeb310a3', 'purchaseUrls.cardmarket': 'https://mtgjson.com/links/50761012051b03e8', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/9c9c0e1ad17f1bdb', 'rulings': "[{'date': '2018-01-19', 'text': 'Any die roll that has a numerical result counts, as long as that result is 4 or greater.'}, {'date': '2018-01-19', 'text': 'If you roll multiple dice at the same time, each one that results in a roll of 4 or greater will cause the ability to trigger.'}]", 'type': 'Enchantment', 'types': 'Enchantment'}, page_content='Whenever you roll a 4 or higher on a die, create a 1/1 green Squirrel creature token.'),
#   0.7759112715),
#  (Document(id='194dc253-8c2a-4bb1-9439-d5acd5e2862e', metadata={'cardName': "Druid's Call", 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 2.0, 'edhrecRank': 9913.0, 'edhrecSaltiness': 0.15, 'firstPrinting': 'ODY', 'foreignData': "[{'flavorText': 'Erdulde die kleinen Kreaturen, denn auch sie können sich erheben und deine Seele aus dir herausprügeln.', 'language': 'German', 'name': 'Ruf des Druiden', 'text': 'Immer wenn der verzauberten Kreatur Schaden zugefügt wird, bringt ihr Beherrscher genausoviel 1/1 grüne Eichhörnchenspielsteine ins Spiel.', 'type': 'Kreaturenverzauberung'}, {'flavorText': 'Que sufran las criaturas pequeñas, porque podrían levantarse y darte una paliza.', 'language': 'Spanish', 'name': 'Llamado de la druida', 'text': 'Siempre que la criatura encantada reciba daño, su controlador pone en juego ese mismo número de fichas de criatura Ardilla verde 1/1.', 'type': 'Encantar criatura'}, {'flavorText': 'Respectez les petites créatures, ou elles se soulèveront et vous renverseront.', 'language': 'French', 'name': 'Appel de la druidesse', 'text': 'À chaque fois que la créature enchantée se voit infliger des blessures, son contrôleur met en jeu autant de jetons de créature 1/1 verte Écureuil.', 'type': 'Enchanter : créature'}, {'flavorText': 'Abbi pazienza con le piccole creature, poiché potrebbero insorgere e colpirti.', 'language': 'Italian', 'name': 'Richiamo del Druido', 'text': 'Ogniqualvolta viene inflitto del danno alla creatura incantata, il suo controllore mette in gioco un pari ammontare di pedine creatura Scoiattolo 1/1 verdi.', 'type': 'Incanta Creatura'}, {'language': 'Japanese', 'name': 'ドルイドの呼び声'}, {'flavorText': 'Tolera as criaturinhas, pois elas podem levantar-se e deixar-te inconsciente.', 'language': 'Portuguese (Brazil)', 'name': 'Chamado do Druida', 'text': 'Toda vez que a criatura encantada sofrer dano, seu controlador coloca em jogo aquela quantidade de fichas de criatura verde 1/1 do tipo Esquilo.', 'type': 'Encantar Criatura'}]", 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': 'e71f4fe8-2ecd-450b-8c41-5e38d749f59d', 'isFunny': False, 'isReserved': False, 'keywords': 'Enchant', 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Legal', 'legalities.premodern': 'Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Legal', 'manaCost': '{1}{G}', 'manaValue': 2.0, 'name': "Druid's Call", 'printings': 'ODY,PLST', 'purchaseUrls.cardKingdom': 'https://mtgjson.com/links/5426f37418a7e9df', 'purchaseUrls.cardmarket': 'https://mtgjson.com/links/ee0daa55089ff62b', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/9746cfe92d9f007f', 'rulings': 'None', 'subtypes': 'Aura', 'type': 'Enchantment — Aura', 'types': 'Enchantment'}, page_content='Enchant creature\nWhenever enchanted creature is dealt damage, its controller creates that many 1/1 green Squirrel creature tokens.'),
#   0.767884344),
#  (Document(id='b25bbb77-1f41-4404-89f3-793a8089bc54', metadata={'cardName': 'Hazel of the Rootbloom', 'colorIdentity': 'B,G', 'colors': 'B,G', 'convertedManaCost': 4.0, 'edhrecRank': 4137.0, 'edhrecSaltiness': 0.48, 'firstPrinting': 'BLC', 'foreignData': "[{'language': 'Japanese', 'name': '根花のヘイゼル', 'text': '{T}, ２点のライフを支払う, あなたがコントロールしていてアンタップ状態であるトークンＸ個をタップする：望む色の組み合わせのマナＸ点を加える。\\nあなたの終了ステップの開始時に、あなたがコントロールしているトークン１つを対象とする。それのコピーであるトークン１つを生成する。対象としたトークンがリスなら、代わりに、それのコピーであるトークン２体を生成する。', 'type': '伝説のクリーチャー — リス・ドルイド'}]", 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': '845b40b1-dc09-44fa-9910-22544c1424ba', 'isFunny': False, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': True, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Not Legal', 'legalities.premodern': 'Not Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Legal', 'manaCost': '{2}{B}{G}', 'manaValue': 4.0, 'name': 'Hazel of the Rootbloom', 'power': '3', 'printings': 'BLC', 'purchaseUrls.cardKingdom': 'https://mtgjson.com/links/042709b806758512', 'purchaseUrls.cardKingdomFoil': 'https://mtgjson.com/links/ce1d79261c55c9ca', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/419c125fd68f0576', 'rulings': '[{\'date\': \'2024-07-26\', \'text\': \'Any "enters" abilities of the copied token will trigger when the token enters. Any "as [this permanent] enters" or "[this permanent] enters with" abilities of the copied token will also work.\'}, {\'date\': \'2024-07-26\', \'text\': \'If the copied token has {X} in its mana cost, X is 0.\'}, {\'date\': \'2024-07-26\', \'text\': \'If the copied token is copying something else (for example, if the copied token is one previously created by this ability), then the token enters as whatever that token copied.\'}, {\'date\': \'2024-07-26\', \'text\': "The token (or tokens) you create copies the original characteristics of the token as stated by the effect that created that token (unless that token is copying something else; see below). It doesn\'t copy whether that token is tapped or untapped, whether it has any counters on it or Auras and Equipment attached to it, or any non-copy effects that have changed its power, toughness, types, color, or so on."}, {\'date\': \'2024-07-26\', \'text\': "You can tap any untapped tokens you control, including creature tokens you control that you haven\'t controlled continuously since the beginning of your most recent turn, to pay the cost of Hazel of the Rootbloom\'s activated ability."}]', 'subtypes': 'Squirrel,Druid', 'supertypes': 'Legendary', 'toughness': '5', 'type': 'Legendary Creature — Squirrel Druid', 'types': 'Creature'}, page_content="{T}, Pay 2 life, Tap X untapped tokens you control: Add X mana in any combination of colors.\nAt the beginning of your end step, create a token that's a copy of target token you control. If that token is a Squirrel, instead create two tokens that are copies of it."),
#   0.767883748),
#  (Document(id='1851edba-eaab-4a30-a00c-5dbde0f3c2f0', metadata={'cardName': 'Scurry Oak', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 3.0, 'edhrecRank': 1956.0, 'edhrecSaltiness': 0.52, 'firstPrinting': 'MH2', 'foreignData': '[{\'language\': \'German\', \'name\': \'Wuselnde Eiche\', \'text\': \'Weiterentwicklung (Immer wenn eine andere Kreatur unter deiner Kontrolle ins Spiel kommt und falls deren Stärke oder Widerstandskraft höher ist, lege eine +1/+1-Marke auf diese Kreatur.)\\nImmer wenn eine oder mehrere +1/+1-Marken auf die Wuselnde Eiche gelegt werden, kannst du einen 1/1 grünen Eichhörnchen-Kreaturenspielstein erzeugen.\', \'type\': \'Kreatur — Baumhirte\'}, {\'language\': \'Spanish\', \'name\': \'Roble ardillero\', \'text\': \'Evolucionar. (Siempre que una criatura entre al campo de batalla bajo tu control, si la fuerza o la resistencia de esa criatura es mayor que la de esta criatura, pon un contador +1/+1 sobre esta criatura.)\\nSiempre que uno o más contadores +1/+1 se pongan sobre el Roble ardillero, puedes crear una ficha de criatura Ardilla verde 1/1.\', \'type\': \'Criatura — Pueblo-arbóreo\'}, {\'language\': \'French\', \'name\': \'Chêne de course\', \'text\': "Évolution (À chaque fois qu\'une créature arrive sur le champ de bataille sous votre contrôle, si sa force ou son endurance est supérieure à celle de cette créature, mettez un marqueur +1/+1 sur cette créature.)\\nÀ chaque fois qu\'au moins un marqueur +1/+1 est mis sur le Chêne de course, vous pouvez créer un jeton de créature 1/1 verte Écureuil.", \'type\': \'Créature : sylvin\'}, {\'language\': \'Italian\', \'name\': \'Quercia Zampettante\', \'text\': \'Evoluzione (Ogniqualvolta una creatura entra nel campo di battaglia sotto il tuo controllo, se quella creatura ha forza o costituzione maggiori di questa creatura, metti un segnalino +1/+1 su questa creatura.)\\nOgniqualvolta uno o più segnalini +1/+1 vengono messi sulla Quercia Zampettante, puoi creare una pedina creatura Scoiattolo 1/1 verde.\', \'type\': \'Creatura — Silvantropo\'}, {\'language\': \'Japanese\', \'name\': \'小走り樫\', \'text\': \'進化（クリーチャー１体があなたのコントロール下で戦場に出るたび、そのクリーチャーのパワーかタフネスがこのクリーチャーよりも大きい場合、このクリーチャーの上に＋１/＋１カウンター１個を置く。）\\n小走り樫の上に１個以上の＋１/＋１カウンターが置かれるたび、あなたは緑の１/１のリス・クリーチャー・トークン１体を生成してもよい。\', \'type\': \'クリーチャー — ツリーフォーク\'}, {\'language\': \'Korean\', \'name\': \'종종걸음 오크나무\', \'text\': \'진화 (생물이 당신의 조종하에 전장에 들어올 때마다, 그 생물의 공격력이 이 생물의 공격력보다 높거나 방어력이 이 생물의 방어력보다 높다면, 이 생물에 +1/+1 카운터 한 개를 올려놓는다.)\\n종종걸음 오크나무에 +1/+1 카운터가 한 개 이상 놓일 때마다, 당신은 1/1 녹색 다람쥐 생물 토큰 한 개를 만들 수 있다.\', \'type\': \'생물 — 인목\'}, {\'language\': \'Portuguese (Brazil)\', \'name\': \'Carvalho Serelepe\', \'text\': \'Evoluir (Toda vez que uma criatura entrar no campo de batalha sob seu controle, se ela tiver poder ou resistência maior que a desta criatura, coloque um marcador +1/+1 nesta criatura.)\\nToda vez que um ou mais marcadores +1/+1 são colocados em Carvalho Serelepe, você pode criar uma ficha de criatura Esquilo verde 1/1.\', \'type\': \'Criatura — Ent\'}, {\'language\': \'Russian\', \'name\': \'Суетливый Дуб\', \'text\': \'Эволюция (Каждый раз, когда существо выходит на поле битвы под вашим контролем, если сила или выносливость того существа больше, чем у этого существа, положите один жетон +1/+1 на это существо.)\\nКаждый раз, когда на Суетливый Дуб кладется один или несколько жетонов +1/+1, вы можете создать одну фишку существа 1/1 зеленая Белка.\', \'type\': \'Существо — Лесовик\'}, {\'language\': \'Chinese Simplified\', \'name\': \'繁声橡树\', \'text\': \'进化（每当一个生物在你的操控下进战场时，若该生物的力量或防御力大于此生物，则在后者上放置一个+1/+1指示物。）\\n每当在繁声橡树上放置一个或数个+1/+1指示物时，你可以派出一个1/1绿色松鼠衍生生物。\', \'type\': \'生物 ～树妖\'}, {\'language\': \'Chinese Traditional\', \'name\': \'繁聲橡樹\', \'text\': \'進化（每當一個生物在你的操控下進戰場時，若該生物的力量或防禦力大於此生物，則在後者上放置一個+1/+1指示物。）\\n每當在繁聲橡樹上放置一個或數個+1/+1指示物時，你可以派出一個1/1綠色松鼠衍生生物。\', \'type\': \'生物 ～樹妖\'}]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': 'eee6c02b-7d6a-4445-ad27-8b03176147d4', 'isFunny': False ...
#   0.7666375935),
#  (Document(id='d4b4e3b8-1583-4423-8586-8ed3444fd918', metadata={'cardName': 'Drey Keeper', 'colorIdentity': 'B,G', 'colors': 'B,G', 'convertedManaCost': 5.0, 'edhrecRank': 8014.0, 'edhrecSaltiness': 0.2, 'firstPrinting': 'MH2', 'foreignData': '[{\'flavorText\': \'Er schenkte den Eichhörnchen Eicheln. Sie schenkten ihm Rache.\', \'language\': \'German\', \'name\': \'Drey-Hüter\', \'text\': \'Wenn der Drey-Hüter ins Spiel kommt, erzeuge zwei 1/1 grüne Eichhörnchen-Kreaturenspielsteine.\\n{3}{B}: Eichhörnchen, die du kontrollierst, erhalten +1/+0 und Bedrohlichkeit bis zum Ende des Zuges.\', \'type\': \'Kreatur — Elf, Druide\'}, {\'flavorText\': \'Dio bellotas a las ardillas. Ellas le dieron la venganza.\', \'language\': \'Spanish\', \'name\': \'Guardián del nido de ardillas\', \'text\': \'Cuando el Guardián del nido de ardillas entre al campo de batalla, crea dos fichas de criatura Ardilla verdes 1/1.\\n{3}{B}: Las Ardillas que controlas obtienen +1/+0 y ganan la habilidad de amenaza hasta el final del turno.\', \'type\': \'Criatura — Druida elfo\'}, {\'flavorText\': \'Il a offert des glands aux écureuils. Ils lui ont offert la vengeance.\', \'language\': \'French\', \'name\': \'Gardien du drai\', \'text\': "Quand le Gardien du drai arrive sur le champ de bataille, créez deux jetons de créature 1/1 verte Écureuil.\\n{3}{B} : Les écureuils que vous contrôlez gagnent +1/+0 et acquièrent la menace jusqu\'à la fin du tour.", \'type\': \'Créature : elfe et druide\'}, {\'flavorText\': \'Ha regalato ghiande agli scoiattoli. Loro gli hanno donato la vendetta.\', \'language\': \'Italian\', \'name\': \'Guardiano della Tana\', \'text\': \'Quando il Guardiano della Tana entra nel campo di battaglia, crea due pedine creatura Scoiattolo 1/1 verdi.\\n{3}{B}: Gli Scoiattoli che controlli prendono +1/+0 e hanno minacciare fino alla fine del turno.\', \'type\': \'Creatura — Druido Elfo\'}, {\'flavorText\': \'彼はリスたちにドングリを提供する。リスたちは彼に復讐を提供する。\', \'language\': \'Japanese\', \'name\': \'リスの巣の守り手\', \'text\': \'リスの巣の守り手が戦場に出たとき、緑の１/１のリス・クリーチャー・トークン２体を生成する。\\n{3}{B}：ターン終了時まで、あなたがコントロールしているすべてのリスは＋１/＋０の修整を受け威迫を得る。\', \'type\': \'クリーチャー — エルフ・ドルイド\'}, {\'flavorText\': \'그는 다람쥐들에게 도토리를 주었다. 다람쥐들은 그가 복수를 하게 해 주었다.\', \'language\': \'Korean\', \'name\': \'다람쥐 사육사\', \'text\': \'다람쥐 사육사가 전장에 들어올 때, 1/1 녹색 다람쥐 생물 토큰 두 개를 만든다.\\n{3}{B}, {T}: 당신이 조종하는 다람쥐들은 턴종료까지 +1/+0을 받고 호전적을 얻는다.\', \'type\': \'생물 — 엘프 드루이드\'}, {\'flavorText\': \'Ele deu bolotas aos esquilos. Eles lhe deram a vingança.\', \'language\': \'Portuguese (Brazil)\', \'name\': \'Guardião da Toca\', \'text\': \'Quando Guardião da Toca entrar no campo de batalha, crie duas fichas de criatura Esquilo verde 1/1.\\n{3}{B}: Os Esquilos que você controla recebem +1/+0 e ganham ameaçar até o final do turno.\', \'type\': \'Criatura — Elfo Druida\'}, {\'flavorText\': \'Он давал белкам желуди. Они дали ему возможность отомстить.\', \'language\': \'Russian\', \'name\': \'Смотритель Гнезда\', \'text\': \'Когда Смотритель Гнезда выходит на поле битвы, создайте две фишки существа 1/1 зеленая Белка.\\n{3}{B}: Белки под вашим контролем получают +1/+0 и Угрозу до конца хода.\', \'type\': \'Существо — Эльф Друид\'}, {\'flavorText\': \'他喂松鼠橡实。松鼠为他复仇。\', \'language\': \'Chinese Simplified\', \'name\': \'松鼠窝守护者\', \'text\': \'当松鼠窝守护者进战场时，派出两个1/1绿色松鼠衍生生物。\\n{3}{B}：直到回合结束，由你操控的松鼠得+1/+0且获得威慑异能。\', \'type\': \'生物 ～妖精／德鲁伊\'}, {\'flavorText\': \'他餵松鼠橡實。松鼠為他復仇。\', \'language\': \'Chinese Traditional\', \'name\': \'松鼠窩守護者\', \'text\': \'當松鼠窩守護者進戰場時，派出兩個1/1綠色松鼠衍生生物。\\n{3}{B}：直到回合結束，由你操控的松鼠得+1/+0且獲得威懾異能。\', \'type\': \'生物 ～妖精／德魯伊\'}]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': '7223ef44-0bfb-4108-810d-134174ff26b0', 'isFunny': False, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'l ...
#   0.762230456),
#  (Document(id='0ca4a77e-1bb7-4c12-8962-2b3bf574537d', metadata={'cardName': 'Nantuko Shrine', 'colorIdentity': 'G', 'colors': 'G', 'convertedManaCost': 3.0, 'edhrecRank': 15612.0, 'edhrecSaltiness': 0.27, 'firstPrinting': 'ODY', 'foreignData': '[{\'language\': \'German\', \'name\': \'Nantuko-Schrein\', \'text\': \'Immer wenn ein Spieler einen Zauberspruch ausspielt, bringt er X 1/1 grüne Eichhörnchenspielsteine ins Spiel, wobei X die Anzahl der Karten mit dem gleichen Namen wie dieser Zauberspruch in allen Friedhöfen ist.\', \'type\': \'Verzauberung\'}, {\'language\': \'Spanish\', \'name\': \'Altar nantuko\', \'text\': \'Siempre que un jugador juegue un hechizo, ese jugador pone en juego X fichas de criatura Ardilla verde 1/1, donde X es el número de cartas que haya en todos los cementerios que tengan el mismo nombre que ese hechizo.\', \'type\': \'Encantamiento\'}, {\'language\': \'French\', \'name\': \'Reliquaire des Nantukos\', \'text\': "À chaque fois qu\'un joueur joue un sort, ce joueur met en jeu X jetons de créature 1/1 verte Écureuil, X étant le nombre de cartes dans tous les cimetières ayant le même nom que ce sort.", \'type\': \'Enchantement\'}, {\'language\': \'Italian\', \'name\': \'Santuario Nantuko\', \'text\': \'Ogniqualvolta un giocatore gioca una magia, quel giocatore mette in gioco X pedine creatura Scoiattolo 1/1 verdi, dove X è pari al numero di carte presenti in tutti i cimiteri con lo stesso nome di quella magia.\', \'type\': \'Incantesimo\'}, {\'language\': \'Japanese\', \'name\': \'ナントゥーコの祭殿\'}, {\'language\': \'Portuguese (Brazil)\', \'name\': \'Sacrário dos Nantukos\', \'text\': \'Toda vez que um jogador joga uma mágica, aquele jogador coloca em jogo X fichas de criatura verde 1/1 do tipo Esquilo, onde X é igual ao número de cards com o mesmo nome daquela mágica em todos os cemitérios.\', \'type\': \'Encantamento\'}]', 'hasAlternativeDeckLimit': False, 'identifiers.scryfallOracleId': 'fc32ec2b-5432-41cc-ab4c-d9f986126392', 'isFunny': False, 'isReserved': False, 'layout': 'normal', 'leadershipSkills.brawl': False, 'leadershipSkills.commander': False, 'leadershipSkills.oathbreaker': False, 'legalities.alchemy': 'Not Legal', 'legalities.brawl': 'Not Legal', 'legalities.commander': 'Legal', 'legalities.duel': 'Legal', 'legalities.explorer': 'Not Legal', 'legalities.future': 'Not Legal', 'legalities.gladiator': 'Not Legal', 'legalities.historic': 'Not Legal', 'legalities.legacy': 'Legal', 'legalities.modern': 'Not Legal', 'legalities.oathbreaker': 'Legal', 'legalities.oldschool': 'Not Legal', 'legalities.pauper': 'Not Legal', 'legalities.paupercommander': 'Not Legal', 'legalities.penny': 'Not Legal', 'legalities.pioneer': 'Not Legal', 'legalities.predh': 'Legal', 'legalities.premodern': 'Legal', 'legalities.standard': 'Not Legal', 'legalities.standardbrawl': 'Not Legal', 'legalities.timeless': 'Not Legal', 'legalities.vintage': 'Legal', 'manaCost': '{1}{G}{G}', 'manaValue': 3.0, 'name': 'Nantuko Shrine', 'printings': 'ODY', 'purchaseUrls.cardKingdom': 'https://mtgjson.com/links/b621352dfd9a83d1', 'purchaseUrls.cardKingdomFoil': 'https://mtgjson.com/links/87e5908fb85b3489', 'purchaseUrls.cardmarket': 'https://mtgjson.com/links/40d8ef01d967f532', 'purchaseUrls.tcgplayer': 'https://mtgjson.com/links/acac74a285f059b5', 'rulings': 'None', 'type': 'Enchantment', 'types': 'Enchantment'}, page_content='Whenever a player casts a spell, that player creates X 1/1 green Squirrel creature tokens, where X is the number of cards in all graveyards with the same name as that spell.'),
#   0.761082232)]

# %%
data = load_json_file()
data
# Out:
# /Users/ccoggins/Documents/Code/GitHub/ai-cookbook/apps/mtg_recommender/src/data/utils.py:93: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)
# /Users/ccoggins/Documents/Code/GitHub/ai-cookbook/apps/mtg_recommender/src/data/utils.py:93: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)
#                              cardName          identifiers.scryfallOracleId  \
# 0                   "Ach! Hans, Run!"  a2c5ee76-6084-413c-bb70-45490d818374
# 1      "Brims" Barone, Midway Mobster  c64c31f2-c1be-414e-9dff-c3b77ba97545
# 2              "Lifetime" Pass Holder  7bf6f13a-3c90-4bda-bc84-e026828bf4d1
# 3               "Name Sticker" Goblin  acee1d16-1651-4e2c-8138-cc6456c4ee71
# 4          "Rumors of My Death . . ."  38bcba8b-2838-4ac8-9976-f9ccaa94fdba
# ...                               ...                                   ...
# 32793            Éomer, King of Rohan  4f8191e6-a6aa-4426-9014-eff4e0efee9e
# 32794         Éomer, Marshal of Rohan  b2d95950-18b3-463f-94f4-299e420751dc
# 32795          Éowyn, Fearless Knight  dcc349e9-399d-4f33-8131-d1801272466a
# 32796            Éowyn, Lady of Rohan  1ee3753c-3b6e-4182-9305-2ab757f485f0
# 32797             Éowyn, Shieldmaiden  98a2a642-a30a-43e7-b47f-4776c22d1cb0
#
#       colorIdentity colors         manaCost convertedManaCost manaValue  \
# 0               G,R    G,R  {2}{R}{R}{G}{G}               6.0       6.0
# 1               B,W    B,W        {3}{W}{B}               5.0       5.0
# 2                 B      B              {B}               1.0       1.0
# 3                 R      R           {2}{R}               3.0       3.0
# 4                 B      B           {2}{B}               3.0       3.0
# ...             ...    ...              ...               ...       ...
# 32793           R,W    R,W        {3}{R}{W}               5.0       5.0
# 32794             R      R        {2}{R}{R}               4.0       4.0
# 32795           R,W    R,W        {2}{R}{W}               4.0       4.0
# 32796             W      W           {2}{W}               3.0       3.0
# 32797         R,U,W  R,U,W     {2}{U}{R}{W}               5.0       5.0
#
#        layout  side faceName  ... edhrecSaltiness firstPrinting printings  \
# 0      normal  None     None  ...            None           UNH       UNH
# 1      normal  None     None  ...            None           UNF       UNF
# 2      normal  None     None  ...             0.5           UNF       UNF
# 3      normal  None     None  ...            None           UNF       UNF
# 4      normal  None     None  ...            None           UST       UST
# ...       ...   ...      ...  ...             ...           ...       ...
# 32793  normal  None     None  ...            0.32           LTC       LTC
# 32794  normal  None     None  ...            0.22           LTR  LTR,PLTR
# 32795  normal  None     None  ...            0.33           LTR  LTR,PLTR
# 32796  normal  None     None  ...            0.11           LTR       LTR
# 32797  normal  None     None  ...            0.42           LTC       LTC
#
#                                              foreignData  hand isFunny  \
# 0                                                     []  None    True
# 1                                                     []  None    True
# 2                                                     []  None   False
# 3                                                     []  None   False
# 4                                                     []  None    True
# ...                                                  ...   ...     ...
# 32793  [{'language': 'German', 'name': 'Éomer, König ...  None   False
# 32794  [{'language': 'German', 'name': 'Éomer, Marsch...  None   False
# 32795  [{'language': 'German', 'name': 'Éowyn, furcht...  None   False
# 32796  [{'language': 'German', 'name': 'Éowyn, Herrin...  None   False
# 32797  [{'language': 'German', 'name': 'Éowyn die Sch...  None   False
#
#       isReserved  life                asciiName  \
# 0          False  None                     None
# 1          False  None                     None
# 2          False  None                     None
# 3          False  None                     None
# 4          False  None                     None
# ...          ...   ...                      ...
# 32793      False  None     Eomer, King of Rohan
# 32794      False  None  Eomer, Marshal of Rohan
# 32795      False  None   Eowyn, Fearless Knight
# 32796      False  None     Eowyn, Lady of Rohan
# 32797      False  None      Eowyn, Shieldmaiden
#
#                                  name
# 0                   "Ach! Hans, Run!"
# 1      "Brims" Barone, Midway Mobster
# 2              "Lifetime" Pass Holder
# 3               "Name Sticker" Goblin
# 4          "Rumors of My Death . . ."
# ...                               ...
# 32793            Éomer, King of Rohan
# 32794         Éomer, Marshal of Rohan
# 32795          Éowyn, Fearless Knight
# 32796            Éowyn, Lady of Rohan
# 32797             Éowyn, Shieldmaiden
#
# [32798 rows x 67 columns]

# %%
sorted(data.columns.tolist())
# Out:
# ['asciiName',
#  'cardName',
#  'colorIdentity',
#  'colorIndicator',
#  'colors',
#  'convertedManaCost',
#  'defense',
#  'edhrecRank',
#  'edhrecSaltiness',
#  'faceConvertedManaCost',
#  'faceManaValue',
#  'faceName',
#  'firstPrinting',
#  'foreignData',
#  'hand',
#  'hasAlternativeDeckLimit',
#  'identifiers.scryfallOracleId',
#  'isFunny',
#  'isReserved',
#  'keywords',
#  'layout',
#  'leadershipSkills.brawl',
#  'leadershipSkills.commander',
#  'leadershipSkills.oathbreaker',
#  'legalities.alchemy',
#  'legalities.brawl',
#  'legalities.commander',
#  'legalities.duel',
#  'legalities.explorer',
#  'legalities.future',
#  'legalities.gladiator',
#  'legalities.historic',
#  'legalities.legacy',
#  'legalities.modern',
#  'legalities.oathbreaker',
#  'legalities.oldschool',
#  'legalities.pauper',
#  'legalities.paupercommander',
#  'legalities.penny',
#  'legalities.pioneer',
#  'legalities.predh',
#  'legalities.premodern',
#  'legalities.standard',
#  'legalities.standardbrawl',
#  'legalities.timeless',
#  'legalities.vintage',
#  'life',
#  'loyalty',
#  'manaCost',
#  'manaValue',
#  'name',
#  'power',
#  'printings',
#  'purchaseUrls.cardKingdom',
#  'purchaseUrls.cardKingdomEtched',
#  'purchaseUrls.cardKingdomFoil',
#  'purchaseUrls.cardmarket',
#  'purchaseUrls.tcgplayer',
#  'purchaseUrls.tcgplayerEtched',
#  'rulings',
#  'side',
#  'subtypes',
#  'supertypes',
#  'text',
#  'toughness',
#  'type',
#  'types']

# %%
samp = data.loc[data['name'] == 'Ulamog, the Ceaseless Hunger']

for c in samp.columns:
    print(f"{c}: {samp[c].values[0]}")
# Out:
# cardName: Ulamog, the Ceaseless Hunger
# identifiers.scryfallOracleId: 0bfa4512-e35a-4c93-b324-80ec659f5a97
# colorIdentity: None
# colors: None
# manaCost: {10}
# convertedManaCost: 10.0
# manaValue: 10.0
# layout: normal
# side: None
# faceName: None
# faceConvertedManaCost: None
# faceManaValue: None
# colorIndicator: None
# keywords: Indestructible
# text: When you cast this spell, exile two target permanents.
# Indestructible
# Whenever Ulamog attacks, defending player exiles the top twenty cards of their library.
# rulings: [{'date': '2015-08-25', 'text': "Cards exiled by Ulamog's first and third abilities are exiled face up."}, {'date': '2015-08-25', 'text': "If the player has less than twenty cards in their library, exile all of them. That player won't lose the game until they have to draw a card from an empty library."}, {'date': '2015-08-25', 'text': "Ulamog's first ability resolves independently of Ulamog once they've both been put on the stack. If Ulamog is countered, that triggered ability will still resolve. That triggered ability will always resolve before Ulamog does."}]
# power: 10
# toughness: 10
# loyalty: None
# defense: None
# hasAlternativeDeckLimit: False
# type: Legendary Creature — Eldrazi
# types: Creature
# subtypes: Eldrazi
# supertypes: Legendary
# leadershipSkills.brawl: False
# leadershipSkills.commander: True
# leadershipSkills.oathbreaker: False
# legalities.alchemy: Not Legal
# legalities.brawl: Legal
# legalities.commander: Legal
# legalities.duel: Legal
# legalities.explorer: Legal
# legalities.future: Not Legal
# legalities.gladiator: Legal
# legalities.historic: Legal
# legalities.legacy: Legal
# legalities.modern: Legal
# legalities.oathbreaker: Legal
# legalities.oldschool: Not Legal
# legalities.pauper: Not Legal
# legalities.paupercommander: Not Legal
# legalities.penny: Not Legal
# legalities.pioneer: Legal
# legalities.predh: Not Legal
# legalities.premodern: Not Legal
# legalities.standard: Not Legal
# legalities.standardbrawl: Not Legal
# legalities.timeless: Legal
# legalities.vintage: Legal
# purchaseUrls.cardKingdom: https://mtgjson.com/links/787e83a2213ae678
# purchaseUrls.cardKingdomEtched: None
# purchaseUrls.cardKingdomFoil: https://mtgjson.com/links/4e5b867c1a7f240d
# purchaseUrls.cardmarket: https://mtgjson.com/links/96a928d1dcc041d5
# purchaseUrls.tcgplayer: https://mtgjson.com/links/4f8003d458afeaf5
# purchaseUrls.tcgplayerEtched: None
# edhrecRank: 1108.0
# edhrecSaltiness: 1.86
# firstPrinting: BFZ
# printings: BFZ,CMM,HA3,PBFZ,SLD
# foreignData: [{'language': 'German', 'name': 'Ulamog, der unermessliche Hunger', 'text': 'Wenn du diesen Zauberspruch wirkst, schicke zwei bleibende Karten deiner Wahl ins Exil.\nUnzerstörbar\nImmer wenn Ulamog, der unermessliche Hunger, angreift, schickt der verteidigende Spieler die obersten zwanzig Karten seiner Bibliothek ins Exil.', 'type': 'Legendäre Kreatur — Eldrazi'}, {'language': 'French', 'name': 'Ulamog, la Voracité insatiable', 'text': "Quand vous lancez ce sort, exilez deux permanents ciblés.\nIndestructible\nÀ chaque fois qu'Ulamog, la Voracité insatiable attaque, le joueur défenseur exile les vingt cartes du dessus de sa bibliothèque.", 'type': 'Créature légendaire — eldrazi'}, {'language': 'Japanese', 'name': '絶え間ない飢餓、ウラモグ', 'text': 'あなたがこの呪文を唱えたとき、パーマネント２つを対象とする。それらを追放する。\n破壊不能\n絶え間ない飢餓、ウラモグが攻撃するたび、防御プレイヤーは自分のライブラリーの一番上にあるカード20枚を追放する。', 'type': '伝説のクリーチャー — エルドラージ'}, {'language': 'Chinese Simplified', 'name': '不休饥渴钨拉莫', 'text': '当你施放此咒语时，放逐两个目标永久物。\n不灭\n每当不休饥渴钨拉莫攻击时，防御牌手放逐其牌库顶的二十张牌。', 'type': '传奇生物 — 奥札奇'}]
# hand: None
# isFunny: False
# isReserved: False
# life: None
# asciiName: None
# name: Ulamog, the Ceaseless Hunger

# %%
null_cols = data.isna().sum().sort_values(ascending=False).reset_index()
null_cols = null_cols.loc[null_cols[0]>0]
null_cols
# Out:
#                              index      0
# 0   purchaseUrls.cardKingdomEtched  32789
# 1     purchaseUrls.tcgplayerEtched  32788
# 2                          defense  32760
# 3                        asciiName  32718
# 4                             life  32691
# 5                             hand  32691
# 6                          loyalty  32458
# 7                   colorIndicator  32436
# 8                    faceManaValue  31252
# 9            faceConvertedManaCost  31252
# 10                            side  31145
# 11                        faceName  31145
# 12                      supertypes  28802
# 13                        keywords  17171
# 14                           power  14936
# 15                       toughness  14936
# 16                 edhrecSaltiness  14227
# 17    purchaseUrls.cardKingdomFoil  13135
# 18         purchaseUrls.cardmarket  12157
# 19                        subtypes  11535
# 20        purchaseUrls.cardKingdom   6443
# 21                          colors   4675
# 22          purchaseUrls.tcgplayer   4102
# 23                   colorIdentity   3372
# 24                      edhrecRank   2882
# 25                        manaCost   2234
# 26                            text    358
# 27                   firstPrinting     59
# 28                       printings      4
# 29                       manaValue      4
# 30               convertedManaCost      4

# %%
for c in null_cols['index'].tolist():
    print('\t',c.upper())
    print(data.loc[data[c].isna(), c].astype(str).value_counts())
# Out:
# 	 PURCHASEURLS.CARDKINGDOMETCHED
# purchaseUrls.cardKingdomEtched
# None    32789
# Name: count, dtype: int64
# 	 PURCHASEURLS.TCGPLAYERETCHED
# purchaseUrls.tcgplayerEtched
# None    32788
# Name: count, dtype: int64
# 	 DEFENSE
# defense
# None    32760
# Name: count, dtype: int64
# 	 ASCIINAME
# asciiName
# None    32718
# Name: count, dtype: int64
# 	 LIFE
# life
# None    32691
# Name: count, dtype: int64
# 	 HAND
# hand
# None    32691
# Name: count, dtype: int64
# 	 LOYALTY
# loyalty
# None    32458
# Name: count, dtype: int64
# 	 COLORINDICATOR
# colorIndicator
# None    32436
# Name: count, dtype: int64
# 	 FACEMANAVALUE
# faceManaValue
# None    31252
# Name: count, dtype: int64
# 	 FACECONVERTEDMANACOST
# faceConvertedManaCost
# None    31252
# Name: count, dtype: int64
# 	 SIDE
# side
# None    31145
# Name: count, dtype: int64
# 	 FACENAME
# faceName
# None    31145
# Name: count, dtype: int64
# 	 SUPERTYPES
# supertypes
# None    28802
# Name: count, dtype: int64
# 	 KEYWORDS
# keywords
# None    17171
# Name: count, dtype: int64
# 	 POWER
# power
# None    14936
# Name: count, dtype: int64
# 	 TOUGHNESS
# toughness
# None    14936
# Name: count, dtype: int64
# 	 EDHRECSALTINESS
# edhrecSaltiness
# None    14227
# Name: count, dtype: int64
# 	 PURCHASEURLS.CARDKINGDOMFOIL
# purchaseUrls.cardKingdomFoil
# None    13135
# Name: count, dtype: int64
# 	 PURCHASEURLS.CARDMARKET
# purchaseUrls.cardmarket
# None    12157
# Name: count, dtype: int64
# 	 SUBTYPES
# subtypes
# None    11535
# Name: count, dtype: int64
# 	 PURCHASEURLS.CARDKINGDOM
# purchaseUrls.cardKingdom
# None    6443
# Name: count, dtype: int64
# 	 COLORS
# colors
# None    4675
# Name: count, dtype: int64
# 	 PURCHASEURLS.TCGPLAYER
# purchaseUrls.tcgplayer
# None    4102
# Name: count, dtype: int64
# 	 COLORIDENTITY
# colorIdentity
# None    3372
# Name: count, dtype: int64
# 	 EDHRECRANK
# edhrecRank
# None    2882
# Name: count, dtype: int64
# 	 MANACOST
# manaCost
# None    2234
# Name: count, dtype: int64
# 	 TEXT
# text
# None    358
# Name: count, dtype: int64
# 	 FIRSTPRINTING
# firstPrinting
# None    59
# Name: count, dtype: int64
# 	 PRINTINGS
# printings
# None    4
# Name: count, dtype: int64
# 	 MANAVALUE
# manaValue
# None    4
# Name: count, dtype: int64
# 	 CONVERTEDMANACOST
# convertedManaCost
# None    4
# Name: count, dtype: int64

# %%
data.loc[data['asciiName'].notna(), 'asciiName']
# Out:
# 466      Adewale, Breaker of Chains
# 911              Altair Ibn-La'Ahad
# 1067     Anduril, Flame of the West
# 1068       Anduril, Narsil Reforged
# 1599      Arna Kennerud, Skycaptain
#                     ...
# 32793          Eomer, King of Rohan
# 32794       Eomer, Marshal of Rohan
# 32795        Eowyn, Fearless Knight
# 32796          Eowyn, Lady of Rohan
# 32797           Eowyn, Shieldmaiden
# Name: asciiName, Length: 80, dtype: object

# %%
import json

with open('data/gold.json', 'r') as f:
    gold = json.load(f)
gold
# Out:
# [{'question': 'What cards that make the most squirrel tokens?',
#   'eval_category': 'functional',
#   'expected_cards': ['Chatterfang, Squirrel General',
#    'Squirrel Nest',
#    'Acorn Harvest',
#    'Chatter of the Squirrel',
#    'Chatterstorm',
#    'Squirrel Mob',
#    'Deranged Hermit',
#    'Krosan Beast']},
#  {'question': 'Find me cards that make zombies bigger',
#   'eval_category': 'functional',
#   'expected_cards': ['Death Baron',
#    'Cemetery Reaper',
#    'Undead Warchief',
#    'Lord of the Accursed',
#    'Zombie Master',
#    'Diregraf Captain',
#    "Liliana's Mastery",
#    'Graf Harvest']},
#  {'question': 'Find me the most efficient exile removal spells',
#   'eval_category': 'functional',
#   'expected_cards': ['Path to Exile',
#    'Swords to Plowshares',
#    'Generous Gift',
#    'Beast Within',
#    "Vraska's Contempt",
#    'Anguished Unmaking',
#    'Utter End',
#    'Vindicate']},
#  {'question': 'What are good white board wipes?',
#   'eval_category': 'functional',
#   'expected_cards': ['Wrath of God',
#    'Day of Judgment',
#    'Supreme Verdict',
#    'Cleansing Nova',
#    'Austere Command',
#    'Farewell',
#    'Terminus',
#    'Martial Coup']},
#  {'question': 'Most mana-efficient creature removal',
#   'eval_category': 'functional',
#   'expected_cards': ['Path to Exile',
#    'Swords to Plowshares',
#    'Lightning Bolt',
#    'Fatal Push',
#    'Dismember',
#    'Unholy Heat',
#    'Condemn',
#    'Rapid Hybridization']},
#  {'question': 'What direct damage spells can target planeswalkers?',
#   'eval_category': 'functional',
#   'expected_cards': ['Lightning Bolt',
#    'Shock',
#    'Lava Spike',
#    'Chain Lightning',
#    'Incinerate',
#    'Searing Spear',
#    'Burst Lightning',
#    'Wild Lightning']},
#  {'question': 'What are efficient ways to destroy enchantments?',
#   'eval_category': 'functional',
#   'expected_cards': ['Disenchant',
#    'Naturalize',
#    'Krosan Grip',
#    "Nature's Claim",
#    'Force of Vigor',
#    'Fragmentize',
#    'Seal of Cleansing',
#    'Tranquility']},
#  {'question': 'Find me cards that prevent damage',
#   'eval_category': 'functional',
#   'expected_cards': ['Fog',
#    'Holy Day',
#    'Ethereal Haze',
#    "Moment's Peace",
#    'Darkness',
#    'Spike Weaver',
#    'Constant Mists',
#    'Prismatic Strands']},
#  {'question': 'Find me cards that are most similar to Rhystic Study',
#   'eval_category': 'similarity',
#   'expected_cards': ['Mystic Remora',
#    'Smothering Tithe',
#    'Esper Sentinel',
#    'Reconnaissance Mission',
#    'Coastal Piracy',
#    'Bident of Thassa',
#    'Consecrated Sphinx',
#    'Mentor of the Meek']},
#  {'question': 'What cards are similar to The Great Henge',
#   'eval_category': 'similarity',
#   'expected_cards': ['Guardian Project',
#    'Beast Whisperer',
#    'Elemental Bond',
#    'Primordial Sage',
#    'Soul of the Harvest',
#    "Lifecrafter's Bestiary",
#    "Garruk's Uprising",
#    'Zendikar Resurgent']},
#  {'question': 'Cheaper alternatives to Mana Crypt',
#   'eval_category': 'similarity',
#   'expected_cards': ['Sol Ring',
#    'Mana Vault',
#    'Chrome Mox',
#    'Mox Diamond',
#    'Lotus Petal',
#    'Simian Spirit Guide',
#    'Elvish Spirit Guide',
#    'Dark Ritual']},
#  {'question': 'Cards that do similar things to Lightning Bolt',
#   'eval_category': 'similarity',
#   'expected_cards': ['Chain Lightning',
#    'Lava Spike',
#    'Shock',
#    'Galvanic Blast',
#    'Burst Lightning',
#    'Searing Spear',
#    'Incinerate',
#    'Wild Lightning']},
#  {'question': 'What are the best ramp spells in rakdos?',
#   'eval_category': 'constrained',
#   'expected_cards': ['Sol Ring',
#    'Arcane Signet',
#    'Rakdos Signet',
#    'Talisman of Indulgence',
#    "Commander's Sphere",
#    'Mind Stone',
#    'Fellwar Stone',
#    'Worn Powerstone',
#    'Dark Ritual',
#    'Cabal Ritual']},
#  {'question': 'What are the best blue counterspells for 2 mana or less?',
#   'eval_category': 'constrained',
#   'expected_cards': ['Counterspell',
#    'Mana Drain',
#    'Swan Song',
#    'Arcane Denial',
#    'Negate',
#    'Dispel',
#    'Mental Misstep',
#    'Flusterstorm']},
#  {'question': 'Find me the strongest mono-black creatures',
#   'eval_category': 'constrained',
#   'expected_cards': ['Griselbrand',
#    'Sheoldred, Whispering One',
#    'Kokusho, the Evening Star',
#    'Grave Titan',
#    'Massacre Wurm',
#    'Phyrexian Obliterator',
#    'Bloodgift Demon',
#    'Gray Merchant of Asphodel']},
#  {'question': 'Show me Standard-legal burn spells',
#   'note': 'Standard legality changes frequently - verify current status',
#   'eval_category': 'constrained',
#   'expected_cards': ['Lightning Bolt',
#    'Play with Fire',
#    'Shock',
#    'Pillar of Flame',
#    'Flame Slash',
#    'Lava Spike',
#    'Incinerate',
#    'Searing Spear']},
#  {'question': 'What are good budget cards for Modern aggro?',
#   'eval_category': 'constrained',
#   'expected_cards': ['Monastery Swiftspear',
#    'Goblin Guide',
#    'Lava Spike',
#    'Lightning Bolt',
#    'Rift Bolt',
#    'Searing Blaze',
#    'Skullcrack',
#    "Atarka's Command"]},
#  {'question': 'Best card draw for 3 mana or less',
#   'eval_category': 'constrained',
#   'expected_cards': ['Rhystic Study',
#    'Phyrexian Arena',
#    'Sylvan Library',
#    'Mystic Remora',
#    'Divination',
#    "Night's Whisper",
#    'Sign in Blood',
#    'Compulsive Research']},
#  {'question': 'What colorless artifacts provide card draw?',
#   'eval_category': 'constrained',
#   'expected_cards': ['Scroll Rack',
#    "Sensei's Divining Top",
#    'Staff of Nin',
#    'Mind Stone',
#    'Hedron Archive',
#    "Commander's Sphere",
#    'Howling Mine',
#    'Temple Bell']},
#  {'question': 'What are the best cards with flashback?',
#   'eval_category': 'mechanical',
#   'expected_cards': ['Faithless Looting',
#    'Deep Analysis',
#    'Think Twice',
#    'Cabal Therapy',
#    'Lingering Souls',
#    'Ancient Grudge',
#    'Dread Return',
#    'Roar of the Wurm']},
#  {'question': 'Show me cards with protection from red',
#   'eval_category': 'mechanical',
#   'expected_cards': ['Knight of Grace',
#    'White Knight',
#    'Silver Knight',
#    'Paladin en-Vec',
#    'Mother of Runes',
#    'Giver of Runes',
#    'Eight-and-a-Half-Tails',
#    'Auriok Champion']},
#  {'question': 'Find me instant speed removal spells',
#   'eval_category': 'mechanical',
#   'expected_cards': ['Path to Exile',
#    'Swords to Plowshares',
#    'Lightning Bolt',
#    'Fatal Push',
#    'Dismember',
#    'Go for the Throat',
#    'Doom Blade',
#    'Terminate']},
#  {'question': 'What creatures have flying and vigilance?',
#   'eval_category': 'mechanical',
#   'expected_cards': ['Serra Angel',
#    'Lyra Dawnbringer',
#    'Baneslayer Angel',
#    'Akroma, Angel of Wrath',
#    'Cloudgoat Ranger',
#    'Conclave Phalanx',
#    'Knight of the White Orchid',
#    'Pristine Angel']},
#  {'question': 'Show me lands that enter untapped',
#   'eval_category': 'mechanical',
#   'expected_cards': ['Shock lands (Steam Vents, Hallowed Fountain, etc.)',
#    'Fetch lands (Polluted Delta, Wooded Foothills, etc.)',
#    'Fast lands (Inspiring Vantage, Concealed Courtyard, etc.)',
#    'Check lands (Clifftop Retreat, Dragonskull Summit, etc.)',
#    'Basic lands (Mountain, Island, Forest, Plains, Swamp)',
#    'Command Tower',
#    'City of Brass',
#    'Mana Confluence']},
#  {'question': 'What cards support a sacrifice theme?',
#   'eval_category': 'thematic',
#   'expected_cards': ['Viscera Seer',
#    'Carrion Feeder',
#    "Ashnod's Altar",
#    'Phyrexian Altar',
#    'Blood Artist',
#    'Zulaport Cutthroat',
#    'Grave Pact',
#    'Dictate of Erebos']},
#  {'question': 'Find me cards for a spellslinger deck',
#   'eval_category': 'thematic',
#   'expected_cards': ['Young Pyromancer',
#    'Monastery Mentor',
#    'Talrand, Sky Summoner',
#    'Thing in the Ice',
#    'Guttersnipe',
#    'Docent of Perfection',
#    'Baral, Chief of Compliance',
#    'Goblin Electromancer']},
#  {'question': 'What are good tribal support cards for elves?',
#   'eval_category': 'thematic',
#   'expected_cards': ['Elvish Archdruid',
#    'Priest of Titania',
#    'Elvish Champion',
#    'Ezuri, Renegade Leader',
#    'Imperious Perfect',
#    'Elvish Clancaller',
#    'Joraga Warcaller',
#    'Craterhoof Behemoth']},
#  {'question': 'What cards let you draw extra cards each turn?',
#   'eval_category': 'conditional',
#   'expected_cards': ['Rhystic Study',
#    'Phyrexian Arena',
#    'Sylvan Library',
#    'Mystic Remora',
#    'Consecrated Sphinx',
#    "Teferi's Ageless Insight",
#    'Well of Lost Dreams',
#    'Howling Mine']},
#  {'question': 'What draws cards when creatures die?',
#   'eval_category': 'conditional',
#   'expected_cards': ['Midnight Reaper',
#    'Grim Haruspex',
#    'Dark Prophecy',
#    'Fecundity',
#    'Evolutionary Leap',
#    'Species Specialist',
#    'Skullclamp',
#    'Harvester of Souls']}]

# %%
from deepeval import evaluate
from deepeval.metrics import (
    AnswerRelevancyMetric,
    FaithfulnessMetric,
    ContextualRelevancyMetric,
    ContextualPrecisionMetric,
    ContextualRecallMetric
)
from deepeval.test_case import LLMTestCase
from deepeval.dataset import EvaluationDataset

DE_MODEL = "gpt-4.1-nano" # "gpt-4.1-mini"
metrics = [
    # How relevant is the generated answer to the question?
    AnswerRelevancyMetric(threshold=0.7, model=DE_MODEL, include_reason=True), 
    # Is the answer grounded in the retrieved context?
    FaithfulnessMetric(threshold=0.7, model=DE_MODEL, include_reason=True), 
    # How relevant are the retrieved cards to the question?
    ContextualRelevancyMetric(threshold=0.7, model=DE_MODEL, include_reason=True), 
    # Are the most relevant cards ranked highest? 
    ContextualPrecisionMetric(threshold=0.7, model=DE_MODEL, include_reason=True), 
    # Did we retrieve all the relevant cards? 
    ContextualRecallMetric(threshold=0.7, model=DE_MODEL, include_reason=True), 
]

# %%
test_cases = []

for i in gold:
    gold_question = i['question']
    gold_context = i['expected_cards']
    gold_expected_output = ','.join(gold_context)
    
    # try it
    K = 100
    retrieved_context = get_context(gold_question, K=K)
    response = query_llm(gold_question, retrieved_context)

    test_case = LLMTestCase(
        input=gold_question,
        actual_output=response,
        expected_output=gold_expected_output,
        retrieval_context=retrieved_context.split('\n')[1:], 
        context=gold_context, 
    )    
    
    test_cases.append(test_case)

# %%
results = evaluate(
    test_cases=test_cases, 
    metrics=metrics, 
)

# %%
results
